# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("OSBS_datasets/Cleaned_data/final_cleaned_dataset.csv")

# Size and columns
print(df.shape)
print(df.columns)
# Out:
# (93760, 36)
# Index(['datetime', 'soilCO2concentrationMean', 'soilCO2concentrationMinimum',
#        'soilCO2concentrationMaximum', 'soilCO2concentrationVariance',
#        'soilTempMean', 'soilTempMinimum', 'soilTempMaximum',
#        'soilTempVariance', 'VSWCMean', 'VSWCMinimum', 'VSWCMaximum',
#        'VSWCVariance', 'VSICMean', 'VSICMinimum', 'VSICMaximum',
#        'VSICVariance', 'windSpeedMean', 'windSpeedMinimum', 'windSpeedMaximum',
#        'windSpeedVariance', 'windDirMean', 'windDirVariance', 'RHMean',
#        'RHMinimum', 'RHMaximum', 'RHVariance', 'tempRHMean', 'tempRHMinimum',
#        'tempRHMaximum', 'tempRHVariance', 'dewTempMean', 'dewTempMinimum',
#        'dewTempMaximum', 'dewTempVariance', 'TFPrecipBulk'],
#       dtype='object')

# %%
df.head()
# Out:
#                     datetime  soilCO2concentrationMean  \
# 0  2021-01-01 00:00:00+00:00                   1520.60
# 1  2021-01-01 00:02:00+00:00                   1523.45
# 2  2021-01-01 00:04:00+00:00                   1521.15
# 3  2021-01-01 00:06:00+00:00                   1517.68
# 4  2021-01-01 00:08:00+00:00                   1523.27
#
#    soilCO2concentrationMinimum  soilCO2concentrationMaximum  \
# 0                      1511.08                      1526.92
# 1                      1512.77                      1533.90
# 2                      1518.53                      1523.81
# 3                      1509.38                      1524.19
# 4                      1515.84                      1531.68
#
#    soilCO2concentrationVariance  soilTempMean  soilTempMinimum  \
# 0                        27.200        16.909           16.903
# 1                        46.440        16.913           16.909
# 2                         3.622        16.918           16.916
# ...

# %%
df.describe().T
# Out:
#                                 count         mean          std       min  \
# soilCO2concentrationMean      93760.0  1906.508374  1381.621047  764.9700
# soilCO2concentrationMinimum   93760.0  1899.816489  1379.431601  760.2700
# soilCO2concentrationMaximum   93760.0  1913.217593  1383.815357  767.7000
# soilCO2concentrationVariance  93760.0    31.998911    39.149581    0.0000
# soilTempMean                  93760.0    21.190367     4.178679   14.9740
# soilTempMinimum               93760.0    21.187479     4.177540   14.9670
# soilTempMaximum               93760.0    21.193251     4.179820   14.9760
# soilTempVariance              93760.0     0.000010     0.000037    0.0000
# VSWCMean                      93760.0     0.056172     0.024605    0.0062
# VSWCMinimum                   93760.0     0.056025     0.024521    0.0000
# VSWCMaximum                   93760.0     0.056365     0.024772    0.0062
# VSWCVariance                  93760.0     0.000002     0.000131    0.0000
# ...

# %%
df[["datetime", "soilCO2concentrationMean", "soilTempMean", "RHMean"]].set_index("datetime").plot(figsize=(15,6))
plt.title("Soil CO2, Soil Temp, and RH over Time")
plt.show()
