# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("OSBS_datasets/Cleaned_data/NEON_30min_aggregated_data.csv",parse_dates=["datetime"])

# %%
df.head()
# Out:
#                    datetime  soilCO2concentrationMean  soilTempMean  VSWCMean  \
# 0 2021-01-01 00:00:00+00:00               1523.192667     16.923000  0.072140
# 1 2021-01-01 00:30:00+00:00               1522.119667     16.949433  0.072170
# 2 2021-01-01 01:00:00+00:00               1515.906000     16.975733  0.072480
# 3 2021-01-01 01:30:00+00:00               1498.878000     17.002767  0.072167
# 4 2021-01-01 02:00:00+00:00               1475.510333     17.029633  0.072253
#
#      VSICMean  windSpeedMean  windDirMean     RHMean  tempRHMean  dewTempMean  \
# 0  965.912500       0.207000   106.407000  81.251667   21.704133    18.301500
# 1  965.468533       0.224667   138.101333  84.152000   21.363967    18.530300
# 2  964.494233       0.283500   102.852500  85.827333   21.361033    18.842533
# 3  965.737833       0.388000   134.620833  86.222667   21.620167    19.170733
# 4  964.854900       0.295167   127.154000  88.225333   21.397933    19.320833
#
#    ...  dewTempMaximum  soilCO2concentrationVariance  soilTempVariance  \
# 0  ...          18.528                    486.454923      3.043082e-11
# 1  ...          18.731                    508.720528      2.069983e-11
# 2  ...          19.015                    641.644236      2.492051e-11
# 3  ...          19.273                    561.388509      2.247016e-11
# 4  ...          19.475                    476.760228      1.909082e-11
#
#    VSWCVariance  VSICVariance  windSpeedVariance  windDirVariance  RHVariance  \
# 0           0.0      0.252561           0.000021     1.372142e+06    0.000575
# 1           0.0      0.210005           0.000026     1.635710e+06    0.000536
# 2           0.0      0.120942           0.000197     6.246535e+05    0.000434
# 3           0.0      0.211221           0.000847     1.553667e+06    0.000094
# 4           0.0      0.293150           0.000231     9.416162e+05    0.000253
#
#    tempRHVariance  dewTempVariance
# 0             0.0     9.609195e-07
# 1             0.0     1.374713e-06
# 2             0.0     1.016092e-06
# 3             0.0     3.333333e-08
# 4             0.0     1.655172e-07
#
# [5 rows x 35 columns]

# %%
df.describe().T
# Out:
#                                  count          mean           std  \
# soilCO2concentrationMean        8613.0  1.514306e+03  4.707630e+02
# soilTempMean                    8613.0  2.111076e+01  3.475946e+00
# VSWCMean                        8613.0  5.732662e-02  1.718189e-02
# VSICMean                        8613.0  8.934210e+02  9.381769e+01
# windSpeedMean                   8613.0  4.981781e-01  2.658872e-01
# windDirMean                     8613.0  1.746426e+02  6.869042e+01
# RHMean                          8613.0  7.490006e+01  1.763504e+01
# tempRHMean                      8613.0  1.886383e+01  5.966606e+00
# dewTempMean                     8613.0  1.360705e+01  6.004290e+00
# soilCO2concentrationMinimum     8613.0  1.502067e+03  4.721515e+02
# soilTempMinimum                 8613.0  2.107063e+01  3.439076e+00
# VSWCMinimum                     8613.0  5.652596e-02  1.676699e-02
# VSICMinimum                     8613.0  8.806257e+02  9.675828e+01
# windSpeedMinimum                8613.0  1.324527e-02  1.884051e-02
# RHMinimum                       8613.0  7.299859e+01  1.815009e+01
# tempRHMinimum                   8613.0  1.853645e+01  5.925383e+00
# dewTempMinimum                  8613.0  1.326092e+01  6.068425e+00
# soilCO2concentrationMaximum     8613.0  1.526654e+03  4.694592e+02
# soilTempMaximum                 8613.0  2.115091e+01  3.512851e+00
# VSWCMaximum                     8613.0  5.960775e-02  1.906488e-02
# VSICMaximum                     8613.0  8.986515e+02  9.565870e+01
# windSpeedMaximum                8613.0  1.702940e+00  8.942394e-01
# RHMaximum                       8613.0  7.667563e+01  1.719376e+01
# tempRHMaximum                   8613.0  1.921894e+01  6.029659e+00
# dewTempMaximum                  8613.0  1.395318e+01  5.940444e+00
# soilCO2concentrationVariance    8613.0  2.384613e+02  1.654766e+02
# soilTempVariance                8613.0  9.207172e-12  1.080547e-11
# VSWCVariance                    8613.0  0.000000e+00  0.000000e+00
# VSICVariance                    8613.0  1.369921e-01  1.426937e-01
# windSpeedVariance               8613.0  9.070395e-04  9.867253e-04
# windDirVariance                 8613.0  1.142261e+06  7.852584e+05
# RHVariance                      8613.0  3.459837e-04  2.926723e-04
# tempRHVariance                  8613.0  0.000000e+00  0.000000e+00
# dewTempVariance                 8613.0  1.349694e-06  1.264704e-06
# VPD                             8613.0  6.542183e-01  5.747589e-01
# soilTempMean_lag1h              8613.0  2.110953e+01  3.475399e+00
# soilTempMean_lag2h              8613.0  2.110823e+01  3.474794e+00
# VSWCMean_lag1h                  8613.0  5.732293e-02  1.718089e-02
# VSWCMean_lag2h                  8613.0  5.731920e-02  1.717988e-02
# soilCO2concentrationMean_lag1h  8613.0  1.513999e+03  4.705124e+02
# soilCO2concentrationMean_lag2h  8613.0  1.513692e+03  4.702616e+02
# VPD_lag1h                       8613.0  6.543883e-01  5.746959e-01
# VPD_lag2h                       8613.0  6.545300e-01  5.746521e-01
#
#                                        min           25%           50%  \
# soilCO2concentrationMean        767.559000  1.178523e+03  1.444189e+03
# soilTempMean                     14.976733  1.904630e+01  2.111076e+01
# VSWCMean                          0.021500  5.433333e-02  5.732662e-02
# VSICMean                        688.622250  8.837990e+02  8.934210e+02
# windSpeedMean                     0.043167  2.875000e-01  4.981781e-01
# windDirMean                       4.652500  1.344050e+02  1.746426e+02
# RHMean                           18.804000  6.593100e+01  7.490006e+01
# tempRHMean                       -0.232500  1.625493e+01  1.886383e+01
# dewTempMean                      -6.044400  1.113880e+01  1.360705e+01
# soilCO2concentrationMinimum     760.040000  1.166290e+03  1.426870e+03
# soilTempMinimum                  14.967000  1.904100e+01  2.107063e+01
# VSWCMinimum                       0.021950  5.400000e-02  5.652596e-02
# VSICMinimum                     688.911000  8.711870e+02  8.806257e+02
# windSpeedMinimum                  0.000000  0.000000e+00  1.000000e-02
# RHMinimum                        17.150000  6.325000e+01  7.299859e+01
# tempRHMinimum                    -0.244500  1.597300e+01  1.853645e+01
# dewTempMinimum                   -6.513000  1.069500e+01  1.326092e+01
# soilCO2concentrationMaximum     774.800000  1.190700e+03  1.463260e+03
# soilTempMaximum                  14.985000  1.905000e+01  2.115091e+01
# VSWCMaximum                       0.021050  5.450000e-02  5.960775e-02
# VSICMaximum                     688.817000  8.869380e+02  8.986515e+02
# windSpeedMaximum                  0.098824  9.300000e-01  1.702940e+00
# RHMaximum                        20.560000  6.839000e+01  7.667563e+01
# tempRHMaximum                    -0.217000  1.659100e+01  1.921894e+01
# dewTempMaximum                   -5.010000  1.160100e+01  1.395318e+01
# soilCO2concentrationVariance      0.000000  8.835208e+01  2.384613e+02
# soilTempVariance                  0.000000  1.758161e-13  9.207172e-12
# VSWCVariance                      0.000000  0.000000e+00  0.000000e+00
# VSICVariance                      0.000000  2.263375e-03  1.369921e-01
# windSpeedVariance                 0.000000  5.678161e-05  9.070395e-04
# windDirVariance                   0.000000  5.541666e+05  1.142261e+06
# RHVariance                        0.000000  3.091954e-05  3.459837e-04
# tempRHVariance                    0.000000  0.000000e+00  0.000000e+00
# dewTempVariance                   0.000000  6.436782e-08  1.349694e-06
# VPD                              -0.094948  2.060092e-01  6.542183e-01
# soilTempMean_lag1h               14.976733  1.904630e+01  2.110953e+01
# soilTempMean_lag2h               14.976733  1.904630e+01  2.110823e+01
# VSWCMean_lag1h                    0.021500  5.433333e-02  5.732293e-02
# VSWCMean_lag2h                    0.021500  5.433333e-02  5.731920e-02
# soilCO2concentrationMean_lag1h  767.559000  1.178523e+03  1.444189e+03
# soilCO2concentrationMean_lag2h  767.559000  1.178523e+03  1.444189e+03
# VPD_lag1h                        -0.094948  2.062043e-01  6.543883e-01
# VPD_lag2h                        -0.094948  2.064728e-01  6.545300e-01
#
#                                          75%           max
# soilCO2concentrationMean        1.514306e+03  2.521878e+03
# soilTempMean                    2.311563e+01  3.065000e+01
# VSWCMean                        6.576000e-02  9.590000e-02
# VSICMean                        9.701462e+02  1.021402e+03
# windSpeedMean                   6.250000e-01  1.430000e+00
# windDirMean                     2.183745e+02  3.543322e+02
# RHMean                          8.886267e+01  1.038787e+02
# tempRHMean                      2.264580e+01  3.355317e+01
# dewTempMean                     1.784597e+01  2.557237e+01
# soilCO2concentrationMinimum     1.502067e+03  2.515093e+03
# soilTempMinimum                 2.308500e+01  3.064800e+01
# VSWCMinimum                     6.460000e-02  9.515000e-02
# VSICMinimum                     9.625030e+02  1.018658e+03
# windSpeedMinimum                1.324527e-02  3.050000e-01
# RHMinimum                       8.713000e+01  1.035700e+02
# tempRHMinimum                   2.233200e+01  3.299600e+01
# dewTempMinimum                  1.755600e+01  2.537100e+01
# soilCO2concentrationMaximum     1.526654e+03  2.528900e+03
# soilTempMaximum                 2.314200e+01  3.065350e+01
# VSWCMaximum                     6.840000e-02  9.665000e-02
# VSICMaximum                     9.765810e+02  1.125231e+03
# windSpeedMaximum                2.230000e+00  3.472500e+00
# RHMaximum                       9.039000e+01  1.047000e+02
# tempRHMaximum                   2.299155e+01  3.425300e+01
# dewTempMaximum                  1.808900e+01  2.587600e+01
# soilCO2concentrationVariance    3.353632e+02  2.028527e+03
# soilTempVariance                1.118162e-11  7.812500e-11
# VSWCVariance                    0.000000e+00  0.000000e+00
# VSICVariance                    1.979120e-01  7.038911e-01
# windSpeedVariance               1.109914e-03  8.461523e-03
# windDirVariance                 1.398598e+06  4.882824e+06
# RHVariance                      5.751724e-04  1.554167e-03
# tempRHVariance                  0.000000e+00  0.000000e+00
# dewTempVariance                 2.188506e-06  8.000000e-06
# VPD                             7.840916e-01  3.399973e+00
# soilTempMean_lag1h              2.310427e+01  3.065000e+01
# soilTempMean_lag2h              2.309703e+01  3.065000e+01
# VSWCMean_lag1h                  6.575333e-02  9.590000e-02
# VSWCMean_lag2h                  6.574333e-02  9.590000e-02
# soilCO2concentrationMean_lag1h  1.513999e+03  2.521878e+03
# soilCO2concentrationMean_lag2h  1.513692e+03  2.521878e+03
# VPD_lag1h                       7.840916e-01  3.399973e+00
# VPD_lag2h                       7.840916e-01  3.399973e+00

# %%
# Compute VPD
T = df['tempRHMean']  # °C
RH = df['RHMean']     # %
e_s = 0.6108 * np.exp((17.27 * T) / (T + 237.3))
e_a = (RH / 100.0) * e_s
df['VPD'] = e_s - e_a

# Create lag features (1h, 2h -> 2 and 4 steps because 30-min)
lag_vars = ['soilTempMean', 'VSWCMean', 'soilCO2concentrationMean', 'VPD']
for var in lag_vars:
    df[f'{var}_lag1h'] = df[var].shift(2)
    df[f'{var}_lag2h'] = df[var].shift(4)

df.fillna(df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# datetime                          0
# soilCO2concentrationMean          0
# soilTempMean                      0
# VSWCMean                          0
# VSICMean                          0
# windSpeedMean                     0
# windDirMean                       0
# RHMean                            0
# tempRHMean                        0
# dewTempMean                       0
# soilCO2concentrationMinimum       0
# soilTempMinimum                   0
# VSWCMinimum                       0
# VSICMinimum                       0
# windSpeedMinimum                  0
# RHMinimum                         0
# tempRHMinimum                     0
# dewTempMinimum                    0
# soilCO2concentrationMaximum       0
# soilTempMaximum                   0
# VSWCMaximum                       0
# VSICMaximum                       0
# windSpeedMaximum                  0
# RHMaximum                         0
# tempRHMaximum                     0
# dewTempMaximum                    0
# soilCO2concentrationVariance      0
# soilTempVariance                  0
# VSWCVariance                      0
# VSICVariance                      0
# windSpeedVariance                 0
# windDirVariance                   0
# RHVariance                        0
# tempRHVariance                    0
# dewTempVariance                   0
# VPD                               0
# soilTempMean_lag1h                0
# soilTempMean_lag2h                0
# VSWCMean_lag1h                    0
# VSWCMean_lag2h                    0
# soilCO2concentrationMean_lag1h    0
# soilCO2concentrationMean_lag2h    0
# VPD_lag1h                         0
# VPD_lag2h                         0
# dtype: int64

# %%
df.shape
# Out:
# (8613, 44)

# %%
df.to_csv('OSBS_datasets/Cleaned_data/cleaned_30min_final_data.csv', index=False)
